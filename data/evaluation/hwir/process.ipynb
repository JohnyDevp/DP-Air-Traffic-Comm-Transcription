# %%
import json
import matplotlib.pyplot as plt
from glob import glob

# %%
js = []
js_dec_24 =  open('Dec24_11-38-59_9264b9c50803.json', 'r')
js_jan_4_17 = open('Jan04_17-05-35_57414cb1c613.json', 'r')
js_jan_4_22 = open('Jan04_22-02-05_dc16027e4dbc.json', 'r')
js_jan_5 = open('Jan05_16-47-35_ab5ffdf143c3.json', 'r')
        
js.extend(json.load(js_dec_24))
js.extend(json.load(js_jan_4_17))
js.extend(json.load(js_jan_4_22))
js.extend(json.load(js_jan_5))

plt.plot([i[0] for i in js],[i[1] for i in js])
plt.xlabel("Kroky během 15 epoch")
plt.ylabel("Loss")
plt.title("Průběh loss při trénování na HIWIRE")
plt.savefig('hiwirte_loss.png', dpi=300)
