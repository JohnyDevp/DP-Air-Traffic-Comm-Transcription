# %%
import json
import matplotlib.pyplot as plt

# %%
file_dec = open("Dec24_10-44-36_6c1b423a138a.json", "r")
file_jan = open("Jan02_10-44-18_d323298622bd.json", "r")
js1 = json.load(file_dec)
js1.extend(json.load(file_jan))

plt.plot([i[0] for i in js1],[i[1] for i in js1])
plt.xlabel("Kroky během 15 epoch")
plt.ylabel("Loss")
plt.title("Průběh loss při trénování na ATCO")
# plt.savefig('atco_loss.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Průběh loss při trénování na ATCO')
